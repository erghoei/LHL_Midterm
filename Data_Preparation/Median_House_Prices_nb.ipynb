# %% [markdown]
# data from
#
# https://www.propertyshark.com/mason/market-trends/residential/nyc-all

# %%
# import pandas
import pandas as pd
# Import train_test_split function
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsRegressor

#import numpy
import numpy as np

import pandas as pd

#to calculate means
import statistics

import sklearn

# %% [markdown]
# # Make Model

# %% [markdown]
# ### Load Data and Set Up Dataframes

# %%
# load data
df = pd.read_csv("nyc_geo_with_median_house_prices.csv")

# %%
df.head()
# Out:
#   nyc_geo_data name median_house_price_new_name Borough  Median Sale Price
# 0         Wakefield                   Wakefield   Bronx           518000.0
# 1        Co-op City                         NaN     NaN                NaN
# 2       Eastchester                 Eastchester   Bronx           335000.0
# 3         Fieldston                   Fieldston   Bronx           322500.0
# 4         Riverdale                   Riverdale   Bronx           335000.0

# %%
final_test_data = df.loc[df['Median Sale Price'].isnull()]

# %%
final_test_data
# Out:
#         nyc_geo_data name median_house_price_new_name Borough  \
# 1              Co-op City                         NaN     NaN
# 6             Marble Hill                         NaN     NaN
# 24            Hunts Point                         NaN     NaN
# 28            Throgs Neck                         NaN     NaN
# 38                      c                         NaN     NaN
# 39         Edgewater Park                         NaN     NaN
# 40            Castle Hill                         NaN     NaN
# 53      Manhattan Terrace                         NaN     NaN
# 71          Cypress Hills                         NaN     NaN
# 73          Starrett City                         NaN     NaN
# 76            Mill Island                         NaN     NaN
# 90              City Line                         NaN     NaN
# 95      East Williamsburg                         NaN     NaN
# 96             North Side                         NaN     NaN
# ...

# %%
total_training_data = df.loc[df['Median Sale Price'].notnull()]

# %%
total_training_data
# Out:
#        nyc_geo_data name median_house_price_new_name    Borough  \
# 0              Wakefield                   Wakefield      Bronx
# 2            Eastchester                 Eastchester      Bronx
# 3              Fieldston                   Fieldston      Bronx
# 4              Riverdale                   Riverdale      Bronx
# 5            Kingsbridge                 Kingsbridge      Bronx
# ..                   ...                         ...        ...
# 296              Madison                     Madison   Brooklyn
# 297            Bronxdale                   Bronxdale      Bronx
# 298             Allerton                    Allerton      Bronx
# 299  Kingsbridge Heights         Kingsbridge Heights      Bronx
# 301         Hudson Yards                Hudson Yards  Manhattan
#
#      Median Sale Price
# 0             518000.0
# 2             335000.0
# 3             322500.0
# 4             335000.0
# 5             620000.0
# ..                 ...
# 296           800000.0
# ...
