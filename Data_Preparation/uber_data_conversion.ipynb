# %%
import pandas as pd

# %%
# save data as variables
uber = pd.read_csv('uber-raw-data-june-15.csv')
zone = pd.read_csv('taxi_zone_lookup.csv')

# %%
# check data quickly
uber
# Out:
#          Unnamed: 0 Dispatching_base_num          Pickup_date  \
# 0                 1               B02764  2015-06-01 10:25:00
# 1                 2               B02764  2015-06-01 10:25:00
# 2                 3               B02764  2015-06-01 10:25:00
# 3                 4               B02764  2015-06-01 10:25:00
# 4                 5               B02764  2015-06-01 10:25:00
# ...             ...                  ...                  ...
# 2816890     2816891               B02836  2015-06-30 22:51:00
# 2816891     2816892               B02836  2015-06-30 22:52:00
# 2816892     2816893               B02836  2015-06-30 23:06:00
# 2816893     2816894               B02836  2015-06-30 23:20:00
# 2816894     2816895               B02836  2015-06-30 23:29:00
#
#         Affiliated_base_num  locationID
# 0                    B02682         107
# 1                    B02764         170
# 2                    B02764         237
# 3                    B02764         229
# 4                    B00013          50
# ...                     ...         ...
# 2816890              B02836         143
# 2816891              B02836          90
# 2816892              B02836         246
# 2816893              B02836         107
# 2816894              B02836         144
#
# [2816895 rows x 5 columns]

# %%
# re-name zone data columns
zone.columns = ['locationID', 'borough', 'zone', 'service_zone']

# %%
zone.head()
# Out:
#    locationID        borough                     zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
# group uber data by locationID and produce count
uber.groupby(by='locationID').count()
# Out:
#             Unnamed: 0  Dispatching_base_num  Pickup_date  Affiliated_base_num
# locationID
# 1                   29                    29           29                   29
# 2                    1                     1            1                    1
# 3                  860                   860          860                  860
# 4                17608                 17608        17608                17608
# 5                   10                    10           10                   10
# ...                ...                   ...          ...                  ...
# 260               4481                  4481         4481                 4481
# 261              14239                 14239        14239                14239
# 262              20909                 20909        20909                20909
# 263              25910                 25910        25910                25910
# 265               1476                  1476         1476                 1476
#
# [259 rows x 4 columns]

# %%
# merge uber data with zone data on locationID
uber1 = uber.merge(zone, how='outer', on='locationID')

# %%
uber1
# Out:
#          Unnamed: 0 Dispatching_base_num          Pickup_date  \
# 0               1.0               B02764  2015-06-01 10:25:00
# 1              14.0               B02764  2015-06-01 10:26:00
# 2              54.0               B02764  2015-06-01 10:28:00
# 3              83.0               B02764  2015-06-01 10:29:00
# 4             108.0               B02764  2015-06-01 10:30:00
# ...             ...                  ...                  ...
# 2816896         NaN                  NaN                  NaN
# 2816897         NaN                  NaN                  NaN
# 2816898         NaN                  NaN                  NaN
# 2816899         NaN                  NaN                  NaN
# 2816900         NaN                  NaN                  NaN
#
#         Affiliated_base_num  locationID        borough  \
# 0                    B02682         107      Manhattan
# 1                    B02764         107      Manhattan
# 2                    B00035         107      Manhattan
# 3                    B02253         107      Manhattan
# 4                    B02764         107      Manhattan
# ...                     ...         ...            ...
# 2816896                 NaN         103      Manhattan
# 2816897                 NaN         104      Manhattan
# 2816898                 NaN         110  Staten Island
# 2816899                 NaN         199          Bronx
# 2816900                 NaN         264        Unknown
#
#                                                   zone service_zone
# 0                                             Gramercy  Yellow Zone
# 1                                             Gramercy  Yellow Zone
# 2                                             Gramercy  Yellow Zone
# 3                                             Gramercy  Yellow Zone
# 4                                             Gramercy  Yellow Zone
# ...                                                ...          ...
# 2816896  Governor's Island/Ellis Island/Liberty Island  Yellow Zone
# 2816897  Governor's Island/Ellis Island/Liberty Island  Yellow Zone
# 2816898                               Great Kills Park    Boro Zone
# 2816899                                  Rikers Island    Boro Zone
# 2816900                                             NV          NaN
#
# [2816901 rows x 8 columns]

# %%
# drop all na values in merged data
uber1.dropna(inplace=True)

# %%
# group data by zone as a count
uber2 = uber1.groupby(by='zone', as_index=False).count()

# %%
# some zone names are conjoined together in uber data with a '/' while these places are considered separate neighborhoods in our nyc_geo data
# first split these places that are conjoined by '/'
uber2['zone'] = uber2['zone'].str.split('/')

# %%
# use explode to separate the split places into different rows as their own neighborhood to match nyc_geo data
uber3 = uber2.explode('zone')

# %%
# drop all columns except two
uber4 = uber3.drop(columns=['Dispatching_base_num', 'Pickup_date', 'Affiliated_base_num', 'locationID', 'borough', 'service_zone'])

# %%
# rename remaining columns to name (to match nyc_geo data) and uber_count (the data we want to join onto nyc_geo data)
uber4.columns = ['name', 'uber_count']

# %%
uber4.reset_index(drop=True, inplace=True)

# %%
# group uber data by name as a sum of their counts now
uber5 = uber4.groupby(by='name', as_index=False).sum()

# %%
# there is a large discrepancy between uber data names and nyc_geo names
# many of the same neighborhoods have minor differences that is making merge impossible without losing too much data (almost 50% data loss)
# another option was to artificially inflate the number of neighborhoods we had with all of these slightly different names
# the chosen method was to preserve the number of original sample points for compatibility with future data joins

# function to fully print entire dataframe for visual
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
print_full(uber5)
# Out:
#                              name  uber_count
# 0                        Allerton         860
# 1                   Alphabet City       17608
# 2                        Annadale          11
# 3                   Arden Heights          10
# 4                        Arrochar         145
# 5                         Arverne         241
# 6                         Astoria       18384
# 7                 Astoria Heights          97
# 8                      Auburndale         647
# 9                    Baisley Park        1697
# 10                     Bath Beach         709
# 11                     Bath Beach         920
# 12              Battery Park City         710
# 13              Battery Park City       29335
# 14                      Bay Ridge        7586
# 15                    Bay Terrace         685
# 16                        Bayside        1964
# 17                   Bedford Park       17455
# 18                   Bedford Park        1449
# 19                      Bellerose         713
# 20                        Belmont        1692
# 21                    Bensonhurst        1870
# 22                    Bensonhurst        2245
# 23                     Bloomfield         195
# 24                   Bloomingdale        4585
# 25                    Boerum Hill       13985
# 26                   Borough Park        3653
# 27                   Breezy Point          42
# 28                      Briarwood        2339
# 29                 Brighton Beach        1000
# 30                  Broad Channel          13
# 31                     Bronx Park         676
# 32                    Bronx River         789
# 33                      Bronxdale         920
# 34               Brooklyn Heights       15627
# 35             Brooklyn Navy Yard        2054
# 36                    Brownsville        2230
# 37                       Bruckner         694
# 38                       Bushwick       16938
# 39                       Bushwick       22380
# 40                Cambria Heights         516
# 252                  Williamsburg        1998
# 253           Springfield Gardens         744
# 254           Springfield Gardens        1000
# 255                Spuyten Duyvil        3379
# 256                     Stapleton         157
# 257                 Starrett City         559
# 258                      Steinway        9831
# 259               Stuyvesant Town       13949
# 260               Stuyvesant Town       13007
# 261                     Sunnyside       11522
# 262                   Sunset Park        2056
# 263                   Sunset Park        7383
# 264                  Sutton Place       33381
# 265              Theatre District       62414
# 266                      Times Sq       62414
# 267                     Todt Hill         189
# 268                   Tottenville           8
# 269                       Tribeca       77462
# 270                    Turtle Bay       33381
# 271                    Turtle Bay       29658
# 272                   Two Bridges       15044
# 273                            UN       29658
# 274                      Union Sq       76718
# 275                     Unionport         968
# 276            University Heights        1300
# 277               Upper East Side       41709
# 278               Upper East Side       52535
# 279               Upper West Side       26108
# 280               Upper West Side       36075
# 281            Van Cortlandt Park         380
# 282         Van Cortlandt Village        1664
# 283                      Van Nest        1636
# 284                  Vinegar Hill       10350
# 285                     Wakefield         810
# 286            Washington Heights        7847
# 287            Washington Heights       10527
# 288                 West Brighton         106
# 289                       Chelsea       55473
# 290                     Concourse        3537
# 291                    West Farms         789
# 292                  West Village       57991
# 293                  West Village       53985
# 294           Westchester Village         968
# 295                   Westerleigh         157
# 296                    Whitestone        1084
# 297                 Willets Point         284
# 298                Williamsbridge        1140
# 299                  Williamsburg       42274
# 300                  Williamsburg       28412
# 301               Windsor Terrace        4733
# 302                     Woodhaven        2058
# 303                      Woodlawn         810
# 304                       Woodrow           5
# 305                      Woodside        4567
# 306            World Trade Center       14239
# 307                     Yorkville       20909
# 308                     Yorkville       25910

# %%
# manually update all discrepancies by manually cross-referencing between uber data names and nyc_geo data names
uber5.at[308, 'name'] = "Yorkville"

# %%
# read nyc_geo data
nyc_geo = pd.read_csv('nyc_geo_dataframe.csv')

# %%
# sorting for clarity
nyc_geo1 = nyc_geo.sort_values(by='name')

# %%
# noticed that there were duplicate names in the nyc_geo data (they had slightly different coordinates but were largely the same place)
nyc_geo2 = nyc_geo1.drop_duplicates(subset='name', keep='first')

# %%
uber6 = uber5.groupby(by='name').sum()

# %%
# merge completed uber data and nyc_geo data
nyc_uber = nyc_geo2.merge(uber6, how='left', on='name')

# %%
# fill all na values in merged data with 0 (this may be changed later as needed)
nyc_uber.fillna(value=0, inplace=True)

# %%
nyc_uber
# Out:
#               name  longitude   latitude  uber_count
# 0         Allerton -73.859319  40.865788       860.0
# 1         Annadale -74.178549  40.538114        11.0
# 2    Arden Heights -74.185887  40.549286        10.0
# 3        Arlington -74.165104  40.635325         0.0
# 4         Arrochar -74.067124  40.596313       145.0
# ..             ...        ...        ...         ...
# 297      Woodhaven -73.858110  40.689887      2058.0
# 298       Woodlawn -73.867315  40.898273       810.0
# 299        Woodrow -74.205246  40.541968         5.0
# 300       Woodside -73.901842  40.746349      4567.0
# 301      Yorkville -73.947118  40.775930     46819.0
#
# [302 rows x 4 columns]

# %%
# save merge data as csv
nyc_uber.to_csv('nyc_uber_data.csv', index=False)
